# %%
import pandas as pd
import numpy as  np
from bs4 import BeautifulSoup

# %% [markdown]
# # ATTRIBUTES INFO:
# 1. PROCESSOR has the following pieces of info:
#  typical value:  "Cortex A35 64-bit Quad Core Processor, 1 GB RAM, 8 GB Storage," describes the key specifications of the processor and associated components in a TV. Here's a breakdown of each piece of information:
#
#     * Cortex A35 64-bit Quad Core Processor: This part describes the central processing unit (CPU) of the TV. Here's what each component means:
#
#         - Cortex A35: This refers to the CPU architecture. The Cortex-A35 is an ARM-based CPU architecture commonly used in various electronic devices, including TVs. It's designed to be energy-efficient.
#         - 64-bit: Indicates that the processor is capable of handling 64-bit instructions. This allows it to work with larger amounts of memory and perform certain tasks more efficiently than 32-bit processors.
#     * Quad Core: Indicates that the processor has four CPU cores. Having multiple cores allows the TV to handle multiple tasks simultaneously, which can improve overall performance, especially when multitasking or running complex applications.
#     * 1 GB RAM: This specifies the amount of random-access memory (RAM) in the TV. RAM is used to temporarily store data that the TV's processor needs for active tasks. In this case, the TV has 1 gigabyte (GB) of RAM, which impacts its ability to run apps, handle multitasking, and provide a smoother user experience. More RAM generally allows for better performance, especially when running multiple apps or handling large files.
#
#     * 8 GB Storage: This indicates the amount of internal storage available in the TV for storing apps, data, and other content. In this case, the TV has 8 gigabytes (GB) of storage capacity. The available storage is used for installing apps, saving settings, and storing downloaded content like movies or apps. More storage allows for more apps and content to be stored on the TV.

# %%
with open('tv.html', 'r') as f:
    content= f.read()

# %%
soup = BeautifulSoup(content, 'html.parser')

# %%
containers = soup.find_all("div", {'class' : "sm-product has-tag has-features has-actions"})
len(containers)
# Out:
# 1020

# %%
name = []
price = []
spec = []
screen_size = []
display = []
wifi = []
smart = []
speakers = []
processor = []
view = []
ports = []

for i in containers: 
    name.append(i.find('h2').text)
    price.append(i.find('span' , {'class' : 'price'}).text)
    
    # spec score
    def extract_spec(container):
        if container.find("div", {'class' : 'score rank-1-bg'}):
            return container.find("div", {'class' : 'score rank-1-bg'}).text[:2]
        elif container.find("div", {'class' : 'score rank-2-bg'}):
            return container.find("div", {'class' : 'score rank-2-bg'}).text[:2]
        elif container.find("div", {'class' : 'score rank-3-bg'}):
            return container.find("div", {'class' : 'score rank-3-bg'}).text[:2]
        elif container.find("div", {'class' : 'score rank-4-bg'}):
            return container.find("div", {'class' : 'score rank-4-bg'}).text[:2]
        elif container.find("div", {'class' : 'score rank-5-bg'}):
            return container.find("div", {'class' : 'score rank-5-bg'}).text[:2]
        else:
            return np.nan
        
    spec.append(extract_spec(i))
    
    # unordered list that has 8 pieces of info
    ul = i.find('ul', {'class' : 'sm-feat specs'}).find_all('li')
    
    # screen size
    try:
        screen_size.append(ul[0].text)
    except:
        screen_size.append(np.nan)
        
    # display
    try:
        display.append(ul[1].text)
    except:
        display.append(np.nan)
        
     # wifi
    try:
        wifi.append(ul[2].text)
    except:
        wifi.append(np.nan)
        
     # smart
    try:
        smart.append(ul[3].text)
    except:
        smart.append(np.nan)
    
     # speaker and output
    try:
        speakers.append(ul[4].text)
    except:
        speakers.append(np.nan)
    
    
     # processor
    try:
        processor.append(ul[5].text)
    except:
        processor.append(np.nan)
    
     # view
    try:
        view.append(ul[6].text)
    except:
        view.append(np.nan)
    
     # port
    try:
        ports.append(ul[7].text)
    except:
        ports.append(np.nan)

# %% [markdown]
# # creating a dataframe

# %%
df = pd.DataFrame(
    {'name' : name,
     'price' : price,
     'rating' : spec,
     'screen_size' : screen_size,
     'display' : display,
     'wifi' : wifi,
     'smart' : smart,
     'speakers' : speakers,
     'processor' : processor,
     'view' : view,
     'ports' : ports
    })

# %%
df.head()
# Out:
#                                                 name      price rating  \
# 0  Acer V Series 32 inch HD Ready Smart QLED TV (...  â‚¹14,999     53
# 1  Xiaomi EA43 43 inch Full HD Smart LED TV (L43M...   â‚¹9,999     53
# 2  LG UR75 43 inch Ultra HD 4K Smart LED TV (43UR...  â‚¹31,990     65
# 3  Samsung CU7700 43 inch Ultra HD 4K Smart LED T...  â‚¹38,900     63
# 4  LG LQ64 32 inch HD Ready Smart LED TV (32LQ640...  â‚¹16,249     48
#
#         screen_size                                  display            wifi  \
# 0  32â€‰in, QLED TV                  1366â€‰xâ€‰768â€‰pixels  Wifi, Ethernet
# 1   43â€‰in, LED TV        Full HD, 1920â€‰xâ€‰1080â€‰pixels  Wifi, Ethernet
# 2   43â€‰in, LED TV  4K Resolution, 3840â€‰xâ€‰2160â€‰pixels  Wifi, Ethernet
# 3   43â€‰in, LED TV  4K Resolution, 3840â€‰xâ€‰2160â€‰pixels  Wifi, Ethernet
# 4   32â€‰in, LED TV                  1366â€‰xâ€‰768â€‰pixels  Wifi, Ethernet
#
#       smart                   speakers  \
# 0  Smart TV  2 Speakers, 30â€‰W Output
# 1  Smart TV  2 Speakers, 16â€‰W Output
# 2  Smart TV  2 Speakers, 20â€‰W Output
# 3  Smart TV  2 Speakers, 20â€‰W Output
# 4  Smart TV  2 Speakers, 16â€‰W Output
#
#                                         processor  \
# 0  Quad Core Processor, 1.5 GB RAM, 16 GB Storage
# 1    Cortex A53 Processor, 1 GB RAM, 8 GB Storage
# 2                       3 HDMI Ports, 2 USB Ports
# 3                          178â€‰Â° Viewing Angle
# 4                          178â€‰Â° Viewing Angle
#
#                                  view                                ports
# 0  Ultra Slim, 178â€‰Â° Viewing Angle            2 HDMI Ports, 2 USB Ports
# 1              178â€‰Â° Viewing Angle            2 HDMI Ports, 2 USB Ports
# 2               Supports Apps & Games  Screen Mirroring / Miracast Support
# 3           2 HDMI Ports, 1 USB Ports                Supports Apps & Games
# 4           3 HDMI Ports, 2 USB Ports  Screen Mirroring / Miracast Support

# %%
df.to_csv('tv_original.csv')

# %%
df['brand'] = df['name'].str.strip().str.split(' ').str.get(0).str.lower()

# %%
df['price'] = df['price'].str.replace('â‚¹','').str.replace(',','').astype(int)

# %%
df['screen_size'] = df['screen_size'].str.replace('â€‰','')

# %%
df['tv_size'] = df['screen_size'].str.split(',').str.get(0)
df['tv_type'] = df['screen_size'].str.split(',').str.get(1)

# %%
df['display'] = df['display'].str.replace('â€‰','')
df['resolution'] = df['display'].str.split(',').str.get(0)
df['pixels'] = df['display'].str.split(',').str.get(1)

# %%
df['speakers'] = df['speakers'].str.replace('â€‰','')

# %%
df['view'] = df['view'].str.replace('â€‰Â°','')

# %%
df['ports'] = df['ports'].str.replace('â€‰','')

# %%
df['wifi'] = df['wifi'].str.replace('â€‰','')

# %%
df['wifi'].unique()
# Out:
# array(['Wifi, Ethernet', 'Wifi', 'Smart TV', 'Ethernet',
#        '2 Speakers, 16W Output', '2 Speakers, 20W Output', 'Smart TV: No',
#        '2 HDMI Ports, 2 USB Ports', '2 Speakers, 24W Output'],
#       dtype=object)

# %%
filt = (df['wifi'].str.contains('Wifi')) | (df['wifi'].str.contains('Wifi, Ethernet')) | (df['wifi'].str.contains('Ethernet'))
temp = df.loc[~filt,:]

# %%
df['name'].unique()
# Out:
# array(['Acer V Series 32 inch HD Ready Smart QLED TV (AR32GR2841VQD)',
#        'Xiaomi EA43 43 inch Full HD Smart LED TV (L43M7-EA)',
#        'LG UR75 43 inch Ultra HD 4K Smart LED TV (43UR7550PSC)',
#        'Samsung CU7700 43 inch Ultra HD 4K Smart LED TV (UA43CU7700KLXL)',
#        'LG LQ64 32 inch HD Ready Smart LED TV (32LQ640BPTA)',
#        'LG UQ73 43 inch Ultra HD 4K Smart LED TV (43UQ7300PTA)',
#        'Xiaomi Redmi X43 43 inch Ultra HD 4K Smart LED TV',
#        'Redmi A Series 2024 32 inch HD Ready Smart LED TV (A32)',
#        'Xiaomi Mi 4A PRO 32-inch HD Ready Smart LED TV',
#        'Samsung CU7700 55 inch Ultra HD 4K Smart LED TV (UA55CU7700KLXL)',
#        'LG LQ64 32 inch Full HD Smart LED TV (32LQ645BPTA)',
#        'Sony Bravia X75L 55 inch Ultra HD 4K Smart LED TV (KD-55X75L)',
#        'Samsung T4380 32 inch HD Ready Smart LED TV (UA32T4380AKXXL)',
#        'LG UR75 55 inch Ultra HD 4K Smart LED TV (55UR7550PSC)',
#        'Xiaomi Mi TV 5 65-inch Ultra HD 4K Smart QLED TV',
#        'Redmi 43 inch Ultra HD 4K Smart LED Fire TV',
#        'Samsung AU7600 43 inch Ultra HD 4K Smart LED TV (UA43AU7600KXXL)',
#        'TCL C645 55 inch Ultra HD 4K Smart QLED TV (55C645)',
#        'Sony Bravia X70L 43 inch Ultra HD 4K Smart LED TV (KD-43X70L)',
#        'Xiaomi A Series 32 inch HD Ready Smart LED TV (L32M8-5AIN)',
#        'Acer V Series 43 inch Ultra HD 4K Smart QLED TV (AR43GR2851VQD)',
#        'LG UR80 43 inch Ultra HD 4K Smart LED TV (43UR8050PSB)',
#        'Haier LE32A7 32 inch HD Ready Smart LED TV',
#        'Samsung The Wall Luxury 292-inch Ultra HD 8K Smart MicroLED TV',
#        'Haier P7 Series 43 inch Ultra HD 4K Smart LED TV (43P7GT)',
#        'TCL T6G 55 inch Ultra HD 4K Smart QLED TV (55T6G)',
#        'Xiaomi Smart TV 5A 32 inch HD Ready Smart LED TV',
#        'Sony Bravia X82L 65 inch Ultra HD 4K Smart LED TV (KD-65X82L)',
#        'LG Objet 65 inch Ultra HD 4K Smart OLED TV',
#        'Kodak 7XPro 55UHDX7XPROBL 55-inch Ultra HD 4K Smart LED TV',
#        'Kodak 7XPro 50UHDX7XPROBL 50-inch Ultra HD 4K Smart LED TV'],
#       dtype=object)

# %%
df['resolution'].unique()
# Out:
# array(['1366x768pixels', 'Full HD', '4K Resolution', '8K Resolution',
#        '1366x728pixels', 'Wifi', '7680x4380pixels', '1920x1083pixels',
#        'HD Ready', '366x768pixels', '1399x768pixels'], dtype=object)

# %%
temp.columns
# Out:
# Index(['name', 'price', 'rating', 'screen_size', 'display', 'wifi', 'smart',
#        'speakers', 'processor', 'view', 'ports', 'brand', 'tv_size', 'tv_type',
#        'resolution', 'pixels'],
#       dtype='object')

# %%
resolution_idx = temp[temp['resolution'].str.contains('pixels')].index

# %%
df.loc[resolution_idx, 'pixels'] = df.loc[resolution_idx,'resolution']
df.loc[resolution_idx,'resolution'] = np.nan

# %%
text = "Haier LE32A7 32 inch HD Ready Smart LED TV"
import re
re.findall('\d+ inch', text)
# Out:
# ['32 inch']

# %%
df['screen_size_from_name'] = df['name'].apply(lambda x: re.findall('\d+ inch', x)).str[0].str.split(' ').str.get(0).astype(float)

# %%
text = df['name'].str.split('inch')[2][1]
re.findall(r'\b(?:Full HD|HD|Ultra HD)\b', text)
# Out:
# ['Ultra HD']

# %%
df['hd'] = df['name'].str.split('inch').str[1].fillna('missing')
df['hd'] = df['hd'].apply(lambda x: re.findall(r'\b(?:Full HD|HD|Ultra HD)\b', x)).str.get(0)

# %%
df['hd'].unique()
# Out:
# array(['HD', 'Full HD', 'Ultra HD', nan], dtype=object)

# %%
df['is_smart'] = df['name'].str.contains('Smart').astype(int)

# %%
pattern = r'\b(?:QLED|LED|MicroLED)\b'
text = 'LG UQ73 43 inch Ultra HD 4K Smart LED TV (43UQ7300PTA)'
re.findall(pattern, text)
# Out:
# ['LED']

# %%
df['led_type'] = df['name'].apply(lambda x: re.findall(r'\b(?:QLED|LED|MicroLED)\b', x)).str[0]

# %%
df.columns
# Out:
# Index(['name', 'price', 'rating', 'screen_size', 'display', 'wifi', 'smart',
#        'speakers', 'processor', 'view', 'ports', 'brand', 'tv_size', 'tv_type',
#        'resolution', 'pixels', 'screen_size_from_name', 'hd', 'is_smart',
#        'led_type'],
#       dtype='object')

# %%
df['rating'] = df['rating'].astype(int)

# %%
df['display'].unique()
# Out:
# array(['1366x768pixels', 'Full HD, 1920x1080pixels',
#        '4K Resolution, 3840x2160pixels', '8K Resolution, 7680x4320pixels',
#        '1366x728pixels', 'Wifi', 'Full HD, 1080x1920pixels',
#        '7680x4380pixels', '1920x1083pixels',
#        '4K Resolution, 2160x3840pixels', '4K Resolution, 3810x2160pixels',
#        '4K Resolution, 3480x2160pixels', 'HD Ready, 1280x720pixels',
#        'HD Ready, 1260x720pixels', '4K Resolution, 3860x2160pixels',
#        '4K Resolution, 840x2160pixels', '366x768pixels', '1399x768pixels',
#        '4K Resolution, 9840x2160pixels'], dtype=object)

# %%
df.loc[:,'display':]
# Out:
#                              display            wifi     smart  \
# 0                     1366x768pixels  Wifi, Ethernet  Smart TV
# 1           Full HD, 1920x1080pixels  Wifi, Ethernet  Smart TV
# 2     4K Resolution, 3840x2160pixels  Wifi, Ethernet  Smart TV
# 3     4K Resolution, 3840x2160pixels  Wifi, Ethernet  Smart TV
# 4                     1366x768pixels  Wifi, Ethernet  Smart TV
# ...                              ...             ...       ...
# 1015  4K Resolution, 3840x2160pixels  Wifi, Ethernet  Smart TV
# 1016  4K Resolution, 9840x2160pixels            Wifi  Smart TV
# 1017  4K Resolution, 3840x2160pixels  Wifi, Ethernet  Smart TV
# 1018  4K Resolution, 3840x2160pixels  Wifi, Ethernet  Smart TV
# 1019  4K Resolution, 3840x2160pixels  Wifi, Ethernet  Smart TV
#
#                       speakers  \
# 0       2 Speakers, 30W Output
# 1       2 Speakers, 16W Output
# 2       2 Speakers, 20W Output
# 3       2 Speakers, 20W Output
# 4       2 Speakers, 16W Output
# ...                        ...
# 1015    2 Speakers, 20W Output
# 1016    2 Speakers, 30W Output
# 1017  4.2 Speakers, 80W Output
# 1018    2 Speakers, 40W Output
# 1019    2 Speakers, 40W Output
#
#                                              processor  \
# 0       Quad Core Processor, 1.5 GB RAM, 16 GB Storage
# 1         Cortex A53 Processor, 1 GB RAM, 8 GB Storage
# 2                            3 HDMI Ports, 2 USB Ports
# 3                               178â€‰Â° Viewing Angle
# 4                               178â€‰Â° Viewing Angle
# ...                                                ...
# 1015    Cortex A35 Processor, 1.5 GB RAM, 8 GB Storage
# 1016                           2 GB RAM, 16 GB Storage
# 1017                            178â€‰Â° Viewing Angle
# 1018  ARM Cortex A53 Processor, 2 GB RAM, 8 GB Storage
# 1019  ARM Cortex A53 Processor, 2 GB RAM, 8 GB Storage
#
#                                view                                ports  \
# 0     Ultra Slim, 178 Viewing Angle            2 HDMI Ports, 2 USB Ports
# 1                 178 Viewing Angle            2 HDMI Ports, 2 USB Ports
# 2             Supports Apps & Games  Screen Mirroring / Miracast Support
# 3         2 HDMI Ports, 1 USB Ports                Supports Apps & Games
# 4         3 HDMI Ports, 2 USB Ports  Screen Mirroring / Miracast Support
# ...                             ...                                  ...
# 1015              178 Viewing Angle            3 HDMI Ports, 2 USB Ports
# 1016              178 Viewing Angle            1 HDMI Ports, 3 USB Ports
# 1017      4 HDMI Ports, 3 USB Ports  Screen Mirroring / Miracast Support
# 1018              178 Viewing Angle            3 HDMI Ports, 2 USB Ports
# 1019              178 Viewing Angle            3 HDMI Ports, 2 USB Ports
#
#         brand  tv_size   tv_type      resolution            pixels  \
# 0        acer     32in   QLED TV  1366x768pixels               NaN
# 1      xiaomi     43in    LED TV         Full HD   1920x1080pixels
# 2          lg     43in    LED TV   4K Resolution   3840x2160pixels
# 3     samsung     43in    LED TV   4K Resolution   3840x2160pixels
# 4          lg     32in    LED TV  1366x768pixels               NaN
# ...       ...      ...       ...             ...               ...
# 1015   xiaomi     70in    LED TV   4K Resolution   3840x2160pixels
# 1016     ndgo     55in    LED TV   4K Resolution   9840x2160pixels
# 1017       lg     65in   OLED TV   4K Resolution   3840x2160pixels
# 1018    kodak  54.72in    LED TV   4K Resolution   3840x2160pixels
# 1019    kodak  49.61in    LED TV   4K Resolution   3840x2160pixels
#
#       screen_size_from_name        hd  is_smart led_type
# 0                      32.0        HD         1     QLED
# 1                      43.0   Full HD         1      LED
# 2                      43.0  Ultra HD         1      LED
# 3                      43.0  Ultra HD         1      LED
# 4                      32.0        HD         1      LED
# ...                     ...       ...       ...      ...
# 1015                   70.0  Ultra HD         1      LED
# 1016                   55.0  Ultra HD         1      LED
# 1017                   65.0  Ultra HD         1      NaN
# 1018                    NaN  Ultra HD         1      LED
# 1019                    NaN  Ultra HD         1      LED
#
# [1020 rows x 16 columns]

# %%
filt = (df['display'].str.contains('resolution')) | (df['display'].str.contains('pixels'))
df.loc[~filt, 'display':]
# Out:
#    display      wifi                   smart                   speakers  \
# 59    Wifi  Smart TV  178â€‰Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
#
#     processor                                 view       ports brand tv_size  \
# 59  3D TV: No  Screen Mirroring / Miracast Support  16"9 Ratio    lg    27in
#
#    tv_type resolution pixels  screen_size_from_name   hd  is_smart led_type
# 59     NaN       Wifi    NaN                   27.0  NaN         0      NaN

# %%
df.loc[59, 'wifi':] = df.loc[59,'wifi':].shift(1).values

# %%
df.loc[59,:]
# Out:
# name                         LG StanbyME 27 inch Wireless TV
# price                                                  99999
# rating                                                    45
# screen_size                                             27in
# display                                                 Wifi
# wifi                                                     NaN
# smart                                               Smart TV
# speakers                              178â€‰Â° Viewing Angle
# processor                          2 HDMI Ports, 2 USB Ports
# view                                               3D TV: No
# ports                    Screen Mirroring / Miracast Support
# brand                                             16"9 Ratio
# tv_size                                                   lg
# tv_type                                                 27in
# resolution                                               NaN
# pixels                                                  Wifi
# screen_size_from_name                                    NaN
# hd                                                      27.0
# is_smart                                                 NaN
# led_type                                                   0
# Name: 59, dtype: object

# %%
df['display'].unique()
# Out:
# array(['1366x768pixels', 'Full HD, 1920x1080pixels',
#        '4K Resolution, 3840x2160pixels', '8K Resolution, 7680x4320pixels',
#        '1366x728pixels', 'Wifi', 'Full HD, 1080x1920pixels',
#        '7680x4380pixels', '1920x1083pixels',
#        '4K Resolution, 2160x3840pixels', '4K Resolution, 3810x2160pixels',
#        '4K Resolution, 3480x2160pixels', 'HD Ready, 1280x720pixels',
#        'HD Ready, 1260x720pixels', '4K Resolution, 3860x2160pixels',
#        '4K Resolution, 840x2160pixels', '366x768pixels', '1399x768pixels',
#        '4K Resolution, 9840x2160pixels'], dtype=object)

# %%
pattern = r'\w+ Resolution'
text = ' 4K Resolution, 3840x2160pixels'
re.findall(pattern, text)
# Out:
# ['4K Resolution']

# %%
df['resolution_type'] = df['display'].apply(lambda x: re.findall( r'\w+ Resolution', x)).str[0]

# %%
pattern = r'\d+x\d+pixels'
text = ' 4K Resolution, 3840x2160pixels'
re.findall(pattern, text)
# Out:
# ['3840x2160pixels']

# %%
df['screen_pixels'] = df['display'].apply(lambda x: re.findall(r'\d+x\d+pixels', x)).str[0].str.replace('pixels','')

# %%
df['display'].unique()
# Out:
# array(['1366x768pixels', 'Full HD, 1920x1080pixels',
#        '4K Resolution, 3840x2160pixels', '8K Resolution, 7680x4320pixels',
#        '1366x728pixels', 'Wifi', 'Full HD, 1080x1920pixels',
#        '7680x4380pixels', '1920x1083pixels',
#        '4K Resolution, 2160x3840pixels', '4K Resolution, 3810x2160pixels',
#        '4K Resolution, 3480x2160pixels', 'HD Ready, 1280x720pixels',
#        'HD Ready, 1260x720pixels', '4K Resolution, 3860x2160pixels',
#        '4K Resolution, 840x2160pixels', '366x768pixels', '1399x768pixels',
#        '4K Resolution, 9840x2160pixels'], dtype=object)

# %%
df['resolution'].isna().sum()
# Out:
# 31

# %%
df.columns
# Out:
# Index(['name', 'price', 'rating', 'screen_size', 'display', 'wifi', 'smart',
#        'speakers', 'processor', 'view', 'ports', 'brand', 'tv_size', 'tv_type',
#        'resolution', 'pixels', 'screen_size_from_name', 'hd', 'is_smart',
#        'led_type', 'resolution_type', 'screen_pixels'],
#       dtype='object')

# %%
df['wifi'].unique()
# Out:
# array(['Wifi, Ethernet', 'Wifi', 'Smart TV', nan, 'Ethernet',
#        '2 Speakers, 16W Output', '2 Speakers, 20W Output', 'Smart TV: No',
#        '2 HDMI Ports, 2 USB Ports', '2 Speakers, 24W Output'],
#       dtype=object)

# %%
df['wifi'] = df['wifi'].fillna('missing')

# %%
df = df.drop(columns=['name', 'display'])

# %%
temp = df[df['wifi'].str.contains('Smart TV')]

# %%
temp.columns
# Out:
# Index(['price', 'rating', 'screen_size', 'wifi', 'smart', 'speakers',
#        'processor', 'view', 'ports', 'brand', 'tv_size', 'tv_type',
#        'resolution', 'pixels', 'screen_size_from_name', 'hd', 'is_smart',
#        'led_type', 'resolution_type', 'screen_pixels'],
#       dtype='object')

# %%
df = df.fillna('missing')

# %%
x = temp.fillna('missing').loc[temp.index, 'wifi':'ports'].shift(1, axis=1).values

# %%
df.loc[temp.index, 'wifi':'ports'] = x

# %%
df.loc[temp.index, 'wifi':'ports']
# Out:
#      wifi         smart                   speakers                  processor  \
# 22    NaN      Smart TV  2 Speakers, 10â€‰W Output  3 HDMI Ports, 2 USB Ports
# 346   NaN  Smart TV: No  2 Speakers, 20â€‰W Output        178Â° Viewing Angle
# 385   NaN  Smart TV: No  2 Speakers, 10â€‰W Output        178Â° Viewing Angle
# 582   NaN  Smart TV: No  2 Speakers, 24â€‰W Output        178Â° Viewing Angle
# 647   NaN  Smart TV: No  2 Speakers, 16â€‰W Output  1 HDMI Ports, 1 USB Ports
# 676   NaN  Smart TV: No  2 Speakers, 10â€‰W Output  2 HDMI Ports, 2 USB Ports
# 708   NaN  Smart TV: No  2 Speakers, 16â€‰W Output  2 HDMI Ports, 2 USB Ports
# 721   NaN  Smart TV: No  2 Speakers, 20â€‰W Output        Quad Core Processor
# 745   NaN  Smart TV: No  2 Speakers, 10â€‰W Output  1 HDMI Ports, 1 USB Ports
# 746   NaN  Smart TV: No  2 Speakers, 20â€‰W Output        178Â° Viewing Angle
# 747   NaN  Smart TV: No  2 Speakers, 24â€‰W Output  2 HDMI Ports, 2 USB Ports
# 752   NaN  Smart TV: No  2 Speakers, 16â€‰W Output  2 HDMI Ports, 2 USB Ports
# 777   NaN  Smart TV: No  2 Speakers, 48â€‰W Output        178Â° Viewing Angle
# 783   NaN  Smart TV: No  2 Speakers, 40â€‰W Output        178Â° Viewing Angle
# 809   NaN      Smart TV  2 Speakers, 24â€‰W Output     1 GB RAM, 8 GB Storage
# 818   NaN  Smart TV: No  2 Speakers, 24â€‰W Output        178Â° Viewing Angle
# 835   NaN  Smart TV: No  2 Speakers, 10â€‰W Output          8Â° Viewing Angle
# 908   NaN  Smart TV: No  2 Speakers, 20â€‰W Output        178Â° Viewing Angle
# 941   NaN  Smart TV: No  2 Speakers, 16â€‰W Output        178Â° Viewing Angle
# 974   NaN  Smart TV: No  2 Speakers, 16â€‰W Output        178Â° Viewing Angle
# 978   NaN  Smart TV: No  2 Speakers, 20â€‰W Output        178Â° Viewing Angle
# 993   NaN  Smart TV: No  2 Speakers, 20â€‰W Output        Quad Core Processor
# 1002  NaN  Smart TV: No  2 Speakers, 16â€‰W Output        178Â° Viewing Angle
# 1007  NaN  Smart TV: No  2 Speakers, 20â€‰W Output        170Â° Viewing Angle
#
#                            view                      ports
# 22        Supports Apps & Games                    60â€‰Hz
# 346   2 HDMI Ports, 2 USB Ports                  3D TV: No
# 385   2 HDMI Ports, 2 USB Ports                  3D TV: No
# 582   2 HDMI Ports, 2 USB Ports       60â€‰Hz, 16:09 Ratio
# 647        60â€‰Hz, 16:09 Ratio                    missing
# 676                     60â€‰Hz                    missing
# 708                   3D TV: No       60â€‰Hz, 16:09 Ratio
# 721      178â€‰Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 745                     60â€‰Hz                    missing
# 746   1 HDMI Ports, 1 USB Ports                16:09 Ratio
# 747        60â€‰Hz, 16:09 Ratio                    missing
# 752                     60â€‰Hz                    missing
# 777   1 HDMI Ports, 2 USB Ports        50â€‰Hz, 16:9 Ratio
# 783   1 HDMI Ports, 2 USB Ports        50â€‰Hz, 16:9 Ratio
# 809      180â€‰Â° Viewing Angle  3 HDMI Ports, 2 USB Ports
# 818   2 HDMI Ports, 2 USB Ports        60â€‰Hz, 16:9 Ratio
# 835   1 HDMI Ports, 1 USB Ports        60â€‰Hz, 16:9 Ratio
# 908   2 HDMI Ports, 2 USB Ports       60â€‰Hz, 16:09 Ratio
# 941   2 HDMI Ports, 2 USB Ports       60â€‰Hz, 16:09 Ratio
# 974   3 HDMI Ports, 1 USB Ports                    60â€‰Hz
# 978   2 HDMI Ports, 2 USB Ports        60â€‰Hz, 16:9 Ratio
# 993      178â€‰Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 1002  2 HDMI Ports, 1 USB Ports                  3D TV: No
# 1007  1 HDMI Ports, 1 USB Ports                  3D TV: No

# %%
df['is_smart'] = df['smart'].apply(lambda x: 0 if 'No' in x else 1)

# %%
df['wifi'].unique()
# Out:
# array(['Wifi, Ethernet', 'Wifi', nan, 'missing', 'Ethernet',
#        '2 Speakers, 16W Output', '2 Speakers, 20W Output',
#        '2 HDMI Ports, 2 USB Ports', '2 Speakers, 24W Output'],
#       dtype=object)

# %%
filt = (df['wifi'].str.contains('Wifi')) | (df['wifi'].str.contains('Ethernet'))
df.loc[~filt]
# Out:
#       price  rating     screen_size                       wifi  \
# 22    11880      41    32in, LED TV                        NaN
# 59    99999      45            27in                    missing
# 289    5590      35    24in, LED TV     2 Speakers, 16W Output
# 296    7999      37    32in, LED TV     2 Speakers, 20W Output
# 346    5499      32    24in, LED TV                        NaN
# 377   12490      29            32in     2 Speakers, 20W Output
# 385   15200      34    24in, LED TV                        NaN
# 582    7649      31    32in, LED TV                        NaN
# 621    7289      34    32in, LED TV     2 Speakers, 20W Output
# 622    5189      29    24in, LED TV     2 Speakers, 20W Output
# 647    5449      26    24in, LED TV                        NaN
# 676    6990      33  31.5in, LED TV                        NaN
# 708    7999      31    24in, LED TV                        NaN
# 721    7499      35    32in, LED TV                        NaN
# 724    8999      32    32in, LED TV  2 HDMI Ports, 2 USB Ports
# 745    6490      26    24in, LED TV                        NaN
# 746    5657      29    24in, LED TV                        NaN
# 747    7299      29    32in, LED TV                        NaN
# 752    7499      28    24in, LED TV                        NaN
# 757    5999      32    24in, LED TV     2 Speakers, 20W Output
# 758    7299      32    32in, LED TV     2 Speakers, 20W Output
# 771    8993      34    32in, LED TV     2 Speakers, 24W Output
# 777    8909      34    32in, LED TV                        NaN
# 783    6399      31    24in, LED TV                        NaN
# 809   17999      60    43in, LED TV                        NaN
# 818    5999      32    24in, LED TV                        NaN
# 835   13835      26    24in, LED TV                        NaN
# 908    7690      37    32in, LED TV                        NaN
# 941    7999      34    32in, LED TV                        NaN
# 974   25990      35    32in, LED TV                        NaN
# 978    8889      32    32in, LED TV                        NaN
# 993    6990      34    24in, LED TV                        NaN
# 1002  13987      33    32in, LED TV                        NaN
# 1007   7690      31    24in, LED TV                        NaN
#
#                        smart                   speakers  \
# 22                  Smart TV  2 Speakers, 10â€‰W Output
# 59                  Smart TV     178â€‰Â° Viewing Angle
# 289   178â€‰Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 296   178â€‰Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 346             Smart TV: No  2 Speakers, 20â€‰W Output
# 377   178â€‰Â° Viewing Angle  2 HDMI Ports, 1 USB Ports
# 385             Smart TV: No  2 Speakers, 10â€‰W Output
# 582             Smart TV: No  2 Speakers, 24â€‰W Output
# 621   178â€‰Â° Viewing Angle  1 HDMI Ports, 2 USB Ports
# 622   178â€‰Â° Viewing Angle  1 HDMI Ports, 2 USB Ports
# 647             Smart TV: No  2 Speakers, 16â€‰W Output
# 676             Smart TV: No  2 Speakers, 10â€‰W Output
# 708             Smart TV: No  2 Speakers, 16â€‰W Output
# 721             Smart TV: No  2 Speakers, 20â€‰W Output
# 724      60â€‰Hz, 16:9 Ratio                    missing
# 745             Smart TV: No  2 Speakers, 10â€‰W Output
# 746             Smart TV: No  2 Speakers, 20â€‰W Output
# 747             Smart TV: No  2 Speakers, 24â€‰W Output
# 752             Smart TV: No  2 Speakers, 16â€‰W Output
# 757   178â€‰Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 758   178â€‰Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 771   178â€‰Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 777             Smart TV: No  2 Speakers, 48â€‰W Output
# 783             Smart TV: No  2 Speakers, 40â€‰W Output
# 809                 Smart TV  2 Speakers, 24â€‰W Output
# 818             Smart TV: No  2 Speakers, 24â€‰W Output
# 835             Smart TV: No  2 Speakers, 10â€‰W Output
# 908             Smart TV: No  2 Speakers, 20â€‰W Output
# 941             Smart TV: No  2 Speakers, 16â€‰W Output
# 974             Smart TV: No  2 Speakers, 16â€‰W Output
# 978             Smart TV: No  2 Speakers, 20â€‰W Output
# 993             Smart TV: No  2 Speakers, 20â€‰W Output
# 1002            Smart TV: No  2 Speakers, 16â€‰W Output
# 1007            Smart TV: No  2 Speakers, 20â€‰W Output
#
#                       processor                       view  \
# 22    3 HDMI Ports, 2 USB Ports      Supports Apps & Games
# 59    2 HDMI Ports, 2 USB Ports                  3D TV: No
# 289         60â€‰Hz, 16:9 Ratio                    missing
# 296         60â€‰Hz, 16:9 Ratio                    missing
# 346         178Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 377                   3D TV: No       60â€‰Hz, 16:09 Ratio
# 385         178Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 582         178Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 621         60â€‰Hz, 16:9 Ratio                    missing
# 622         60â€‰Hz, 16:9 Ratio                    missing
# 647   1 HDMI Ports, 1 USB Ports       60â€‰Hz, 16:09 Ratio
# 676   2 HDMI Ports, 2 USB Ports                    60â€‰Hz
# 708   2 HDMI Ports, 2 USB Ports                  3D TV: No
# 721         Quad Core Processor     178â€‰Â° Viewing Angle
# 724                     missing                    missing
# 745   1 HDMI Ports, 1 USB Ports                    60â€‰Hz
# 746         178Â° Viewing Angle  1 HDMI Ports, 1 USB Ports
# 747   2 HDMI Ports, 2 USB Ports       60â€‰Hz, 16:09 Ratio
# 752   2 HDMI Ports, 2 USB Ports                    60â€‰Hz
# 757         60â€‰Hz, 16:9 Ratio                    missing
# 758         60â€‰Hz, 16:9 Ratio                    missing
# 771         60â€‰Hz, 16:9 Ratio                    missing
# 777         178Â° Viewing Angle  1 HDMI Ports, 2 USB Ports
# 783         178Â° Viewing Angle  1 HDMI Ports, 2 USB Ports
# 809      1 GB RAM, 8 GB Storage     180â€‰Â° Viewing Angle
# 818         178Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 835           8Â° Viewing Angle  1 HDMI Ports, 1 USB Ports
# 908         178Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 941         178Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 974         178Â° Viewing Angle  3 HDMI Ports, 1 USB Ports
# 978         178Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 993         Quad Core Processor     178â€‰Â° Viewing Angle
# 1002        178Â° Viewing Angle  2 HDMI Ports, 1 USB Ports
# 1007        170Â° Viewing Angle  1 HDMI Ports, 1 USB Ports
#
#                                     ports       brand tv_size  tv_type  \
# 22                                60â€‰Hz       haier    32in   LED TV
# 59    Screen Mirroring / Miracast Support  16"9 Ratio      lg     27in
# 289                               missing       croma    24in   LED TV
# 296                               missing        acer    32in   LED TV
# 346                             3D TV: No        marq    24in   LED TV
# 377                               missing     samsung    32in  missing
# 385                             3D TV: No     samsung    24in   LED TV
# 582                  60â€‰Hz, 16:09 Ratio        marq    32in   LED TV
# 621                               missing   xelectron    32in   LED TV
# 622                               missing   xelectron    24in   LED TV
# 647                               missing   beethosol    24in   LED TV
# 676                               missing       leema  31.5in   LED TV
# 708                  60â€‰Hz, 16:09 Ratio      compaq    24in   LED TV
# 721             2 HDMI Ports, 2 USB Ports     dyanora    32in   LED TV
# 724                               missing      garuda    32in   LED TV
# 745                               missing       leema    24in   LED TV
# 746                           16:09 Ratio       adsun    24in   LED TV
# 747                               missing     gangnam    32in   LED TV
# 752                               missing        itel    24in   LED TV
# 757                               missing          vw    24in   LED TV
# 758                               missing          vw    32in   LED TV
# 771                               missing       intex    32in   LED TV
# 777                   50â€‰Hz, 16:9 Ratio    cellecor    32in   LED TV
# 783                   50â€‰Hz, 16:9 Ratio    cellecor    24in   LED TV
# 809             3 HDMI Ports, 2 USB Ports     skytron    43in   LED TV
# 818                   60â€‰Hz, 16:9 Ratio        marq    24in   LED TV
# 835                   60â€‰Hz, 16:9 Ratio          lg    24in   LED TV
# 908                  60â€‰Hz, 16:09 Ratio      karbon    32in   LED TV
# 941                  60â€‰Hz, 16:09 Ratio     hyundai    32in   LED TV
# 974                               60â€‰Hz       haier    32in   LED TV
# 978                   60â€‰Hz, 16:9 Ratio      compaq    32in   LED TV
# 993             2 HDMI Ports, 2 USB Ports      sansui    24in   LED TV
# 1002                            3D TV: No         tcl    32in   LED TV
# 1007                            3D TV: No        akai    24in   LED TV
#
#          resolution            pixels screen_size_from_name       hd  \
# 22          missing    1366x768pixels                  32.0       HD
# 59          missing              Wifi               missing     27.0
# 289         missing    1366x768pixels                  24.0       HD
# 296         missing    1366x768pixels                  32.0       HD
# 346         missing    1366x768pixels               missing       HD
# 377         missing    1366x768pixels               missing       HD
# 385         missing    1366x768pixels               missing       HD
# 582         missing    1366x768pixels                  32.0       HD
# 621         missing    1366x768pixels                  32.0       HD
# 622         missing    1366x768pixels                  24.0       HD
# 647         missing    1366x768pixels                  24.0       HD
# 676         Full HD   1920x1080pixels                  32.0  Full HD
# 708         missing    1366x768pixels                  24.0       HD
# 721         missing    1366x768pixels                  32.0       HD
# 724         missing    1366x768pixels                  32.0       HD
# 745         missing    1366x768pixels                  24.0       HD
# 746         missing    1366x768pixels                  24.0       HD
# 747         missing    1366x768pixels                  32.0       HD
# 752         missing    1366x768pixels                  24.0       HD
# 757         missing    1366x768pixels                  24.0       HD
# 758         missing    1366x768pixels                  32.0       HD
# 771         missing    1366x768pixels                  32.0       HD
# 777         Full HD   1920x1080pixels                  32.0       HD
# 783         missing    1366x768pixels                  24.0       HD
# 809   4K Resolution   3840x2160pixels               missing  missing
# 818         missing    1366x768pixels               missing       HD
# 835         missing    1366x768pixels                  24.0       HD
# 908         missing    1366x768pixels                  32.0       HD
# 941         missing    1366x768pixels                  32.0       HD
# 974         missing    1366x768pixels                  32.0       HD
# 978         missing    1366x768pixels                  32.0       HD
# 993         missing    1366x768pixels               missing  missing
# 1002        missing    1366x768pixels                  32.0       HD
# 1007        missing    1366x768pixels               missing  missing
#
#       is_smart led_type resolution_type screen_pixels
# 22           1      LED         missing      1366x768
# 59           1        0         missing       missing
# 289          1      LED         missing      1366x768
# 296          1      LED         missing      1366x768
# 346          0      LED         missing      1366x768
# 377          1      LED         missing      1366x768
# 385          0      LED         missing      1366x768
# 582          0      LED         missing      1366x768
# 621          1      LED         missing      1366x768
# 622          1      LED         missing      1366x768
# 647          0      LED         missing      1366x768
# 676          0      LED         missing     1920x1080
# 708          0      LED         missing      1366x768
# 721          0      LED         missing      1366x768
# 724          1      LED         missing      1366x768
# 745          0      LED         missing      1366x768
# 746          0      LED         missing      1366x768
# 747          0      LED         missing      1366x768
# 752          0      LED         missing      1366x768
# 757          1      LED         missing      1366x768
# 758          1      LED         missing      1366x768
# 771          1      LED         missing      1366x768
# 777          0      LED         missing     1920x1080
# 783          0      LED         missing      1366x768
# 809          1      LED   4K Resolution     3840x2160
# 818          0      LED         missing      1366x768
# 835          0      LED         missing      1366x768
# 908          0      LED         missing      1366x768
# 941          0      LED         missing      1366x768
# 974          0      LED         missing      1366x768
# 978          0      LED         missing      1366x768
# 993          0      LED         missing      1366x768
# 1002         0      LED         missing      1366x768
# 1007         0      LED         missing      1366x768

# %%
df.loc[724]
# Out:
# price                                         8999
# rating                                          32
# screen_size                           32in, LED TV
# wifi                     2 HDMI Ports, 2 USB Ports
# smart                          60â€‰Hz, 16:9 Ratio
# speakers                                   missing
# processor                                  missing
# view                                       missing
# ports                                      missing
# brand                                       garuda
# tv_size                                       32in
# tv_type                                     LED TV
# resolution                                 missing
# pixels                              1366x768pixels
# screen_size_from_name                         32.0
# hd                                              HD
# is_smart                                         1
# led_type                                       LED
# resolution_type                            missing
# screen_pixels                             1366x768
# Name: 724, dtype: object

# %%
df.loc[724,'view'] = df.loc[724,'smart']
df.loc[724,'ports'] = df.loc[724,'wifi']
df.loc[724, ['smart', 'wifi']] = np.nan

# %%
filt = (df['wifi'].str.contains('Wifi')) | (df['wifi'].str.contains('Ethernet'))
df.loc[~filt]
# Out:
#       price  rating     screen_size                    wifi  \
# 22    11880      41    32in, LED TV                     NaN
# 59    99999      45            27in                 missing
# 289    5590      35    24in, LED TV  2 Speakers, 16W Output
# 296    7999      37    32in, LED TV  2 Speakers, 20W Output
# 346    5499      32    24in, LED TV                     NaN
# 377   12490      29            32in  2 Speakers, 20W Output
# 385   15200      34    24in, LED TV                     NaN
# 582    7649      31    32in, LED TV                     NaN
# 621    7289      34    32in, LED TV  2 Speakers, 20W Output
# 622    5189      29    24in, LED TV  2 Speakers, 20W Output
# 647    5449      26    24in, LED TV                     NaN
# 676    6990      33  31.5in, LED TV                     NaN
# 708    7999      31    24in, LED TV                     NaN
# 721    7499      35    32in, LED TV                     NaN
# 724    8999      32    32in, LED TV                     NaN
# 745    6490      26    24in, LED TV                     NaN
# 746    5657      29    24in, LED TV                     NaN
# 747    7299      29    32in, LED TV                     NaN
# 752    7499      28    24in, LED TV                     NaN
# 757    5999      32    24in, LED TV  2 Speakers, 20W Output
# 758    7299      32    32in, LED TV  2 Speakers, 20W Output
# 771    8993      34    32in, LED TV  2 Speakers, 24W Output
# 777    8909      34    32in, LED TV                     NaN
# 783    6399      31    24in, LED TV                     NaN
# 809   17999      60    43in, LED TV                     NaN
# 818    5999      32    24in, LED TV                     NaN
# 747   2 HDMI Ports, 2 USB Ports       60â€‰Hz, 16:09 Ratio
# 752   2 HDMI Ports, 2 USB Ports                    60â€‰Hz
# 757         60â€‰Hz, 16:9 Ratio                    missing
# 758         60â€‰Hz, 16:9 Ratio                    missing
# 771         60â€‰Hz, 16:9 Ratio                    missing
# 777         178Â° Viewing Angle  1 HDMI Ports, 2 USB Ports
# 783         178Â° Viewing Angle  1 HDMI Ports, 2 USB Ports
# 809      1 GB RAM, 8 GB Storage     180â€‰Â° Viewing Angle
# 818         178Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 835           8Â° Viewing Angle  1 HDMI Ports, 1 USB Ports
# 908         178Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 941         178Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 974         178Â° Viewing Angle  3 HDMI Ports, 1 USB Ports
# 978         178Â° Viewing Angle  2 HDMI Ports, 2 USB Ports
# 993         Quad Core Processor     178â€‰Â° Viewing Angle
# 1002        178Â° Viewing Angle  2 HDMI Ports, 1 USB Ports
# 1007        170Â° Viewing Angle  1 HDMI Ports, 1 USB Ports
#
#                                     ports       brand tv_size  tv_type  \
# 22                                60â€‰Hz       haier    32in   LED TV
# 59    Screen Mirroring / Miracast Support  16"9 Ratio      lg     27in
# 289                               missing       croma    24in   LED TV
# 296                               missing        acer    32in   LED TV
# 346                             3D TV: No        marq    24in   LED TV
# 377                               missing     samsung    32in  missing
# 385                             3D TV: No     samsung    24in   LED TV
# 582                  60â€‰Hz, 16:09 Ratio        marq    32in   LED TV
# 621                               missing   xelectron    32in   LED TV
# 622                               missing   xelectron    24in   LED TV
# 647                               missing   beethosol    24in   LED TV
# 676                               missing       leema  31.5in   LED TV
# 708                  60â€‰Hz, 16:09 Ratio      compaq    24in   LED TV
# 721             2 HDMI Ports, 2 USB Ports     dyanora    32in   LED TV
# 724             2 HDMI Ports, 2 USB Ports      garuda    32in   LED TV
# 745                               missing       leema    24in   LED TV
# 746                           16:09 Ratio       adsun    24in   LED TV
# 747                               missing     gangnam    32in   LED TV
# 752                               missing        itel    24in   LED TV
# 757                               missing          vw    24in   LED TV
# 758                               missing          vw    32in   LED TV
# 771                               missing       intex    32in   LED TV
# 777                   50â€‰Hz, 16:9 Ratio    cellecor    32in   LED TV
# 783                   50â€‰Hz, 16:9 Ratio    cellecor    24in   LED TV
# 809             3 HDMI Ports, 2 USB Ports     skytron    43in   LED TV
# 818                   60â€‰Hz, 16:9 Ratio        marq    24in   LED TV
# 835                   60â€‰Hz, 16:9 Ratio          lg    24in   LED TV
# 908                  60â€‰Hz, 16:09 Ratio      karbon    32in   LED TV
# 941                  60â€‰Hz, 16:09 Ratio     hyundai    32in   LED TV
# 974                               60â€‰Hz       haier    32in   LED TV
# 978                   60â€‰Hz, 16:9 Ratio      compaq    32in   LED TV
# 993             2 HDMI Ports, 2 USB Ports      sansui    24in   LED TV
# 1002                            3D TV: No         tcl    32in   LED TV
# 1007                            3D TV: No        akai    24in   LED TV
#
#          resolution            pixels screen_size_from_name       hd  \
# 22          missing    1366x768pixels                  32.0       HD
# 59          missing              Wifi               missing     27.0
# 289         missing    1366x768pixels                  24.0       HD
# 296         missing    1366x768pixels                  32.0       HD
# 346         missing    1366x768pixels               missing       HD
# 377         missing    1366x768pixels               missing       HD
# 385         missing    1366x768pixels               missing       HD
# 582         missing    1366x768pixels                  32.0       HD
# 621         missing    1366x768pixels                  32.0       HD
# 622         missing    1366x768pixels                  24.0       HD
# 647         missing    1366x768pixels                  24.0       HD
# 676         Full HD   1920x1080pixels                  32.0  Full HD
# 708         missing    1366x768pixels                  24.0       HD
# 721         missing    1366x768pixels                  32.0       HD
# 724         missing    1366x768pixels                  32.0       HD
# 745         missing    1366x768pixels                  24.0       HD
# 746         missing    1366x768pixels                  24.0       HD
# 747         missing    1366x768pixels                  32.0       HD
# 752         missing    1366x768pixels                  24.0       HD
# 757         missing    1366x768pixels                  24.0       HD
# 758         missing    1366x768pixels                  32.0       HD
# 771         missing    1366x768pixels                  32.0       HD
# 777         Full HD   1920x1080pixels                  32.0       HD
# 783         missing    1366x768pixels                  24.0       HD
# 809   4K Resolution   3840x2160pixels               missing  missing
# 818         missing    1366x768pixels               missing       HD
# 835         missing    1366x768pixels                  24.0       HD
# 908         missing    1366x768pixels                  32.0       HD
# 941         missing    1366x768pixels                  32.0       HD
# 974         missing    1366x768pixels                  32.0       HD
# 978         missing    1366x768pixels                  32.0       HD
# 993         missing    1366x768pixels               missing  missing
# 1002        missing    1366x768pixels                  32.0       HD
# 1007        missing    1366x768pixels               missing  missing
#
#       is_smart led_type resolution_type screen_pixels
# 22           1      LED         missing      1366x768
# 59           1        0         missing       missing
# 289          1      LED         missing      1366x768
# 296          1      LED         missing      1366x768
# 346          0      LED         missing      1366x768
# 377          1      LED         missing      1366x768
# 385          0      LED         missing      1366x768
# 582          0      LED         missing      1366x768
# 621          1      LED         missing      1366x768
# 622          1      LED         missing      1366x768
# 647          0      LED         missing      1366x768
# 676          0      LED         missing     1920x1080
# 708          0      LED         missing      1366x768
# 721          0      LED         missing      1366x768
# 724          1      LED         missing      1366x768
# 745          0      LED         missing      1366x768
# 746          0      LED         missing      1366x768
# 747          0      LED         missing      1366x768
# 752          0      LED         missing      1366x768
# 757          1      LED         missing      1366x768
# 758          1      LED         missing      1366x768
# 771          1      LED         missing      1366x768
# 777          0      LED         missing     1920x1080
# 783          0      LED         missing      1366x768
# 809          1      LED   4K Resolution     3840x2160
# 818          0      LED         missing      1366x768
# 835          0      LED         missing      1366x768
# 908          0      LED         missing      1366x768
# 941          0      LED         missing      1366x768
# 974          0      LED         missing      1366x768
# 978          0      LED         missing      1366x768
# 993          0      LED         missing      1366x768
# 1002         0      LED         missing      1366x768
# 1007         0      LED         missing      1366x768

# %%
idx = [289,296,377,621,622,757,758,771]
temp = df.loc[idx]
x = temp.loc[:,'wifi':'ports'].shift(2, axis=1)

# %%
df.loc[idx, 'wifi':'ports'] = x

# %%
df['smart'] = df['smart'].fillna('missing')

# %%
filt = (df['smart'].str.contains('Smart')) |(df['smart'].str.contains('missing'))
temp = df.loc[~filt]

# %%
x = temp.loc[:,'smart':'ports'].shift(1, axis=1).values
df.loc[temp.index, 'smart':'ports'] = x

# %%
df.loc[~filt]
# Out:
#       price  rating   screen_size            wifi smart  \
# 194    7190      32  32in, LED TV        Ethernet   NaN
# 231    7190      32  32in, LED TV        Ethernet   NaN
# 413    7590      32  32in, LED TV        Ethernet   NaN
# 819   82480      51  55in, LED TV        Ethernet   NaN
# 952   64990      69  55in, LED TV  Wifi, Ethernet   NaN
# 953  102990      74  65in, LED TV  Wifi, Ethernet   NaN
# 957   42490      65  43in, LED TV  Wifi, Ethernet   NaN
#
#                       speakers                                     processor  \
# 194  2 Speakers, 20â€‰W Output                     2 HDMI Ports, 2 USB Ports
# 231  2 Speakers, 20â€‰W Output                     2 HDMI Ports, 2 USB Ports
# 413  2 Speakers, 20â€‰W Output                     2 HDMI Ports, 2 USB Ports
# 819  2 Speakers, 10â€‰W Output  4K HDR Processor X1 Processor, 16 GB Storage
# 952  2 Speakers, 20â€‰W Output                           178Â° Viewing Angle
# 953     178â€‰Â° Viewing Angle                     3 HDMI Ports, 2 USB Ports
# 957  2 Speakers, 20â€‰W Output                           178Â° Viewing Angle
#
#                                     view                                ports  \
# 194                           16:9 Ratio                              missing
# 231                           16:9 Ratio                              missing
# 413                           16:9 Ratio                              missing
# 819               178â€‰Â° Viewing Angle                            3D TV: No
# 952            3 HDMI Ports, 2 USB Ports  Screen Mirroring / Miracast Support
# 953  Screen Mirroring / Miracast Support                  50â€‰Hz, 16:9 Ratio
# 957            3 HDMI Ports, 2 USB Ports  Screen Mirroring / Miracast Support
#
#        brand tv_size  tv_type      resolution            pixels  \
# 194    croma    32in   LED TV  1366x768pixels           missing
# 231    croma    32in   LED TV  1366x768pixels           missing
# 413    croma    32in   LED TV  1366x768pixels           missing
# 819     sony    55in   LED TV   4K Resolution   3840x2160pixels
# 952  samsung    55in   LED TV   4K Resolution   3840x2160pixels
# 953  samsung    65in   LED TV   4K Resolution   3840x2160pixels
# 957  samsung    43in   LED TV   4K Resolution   3840x2160pixels
#
#     screen_size_from_name        hd  is_smart led_type resolution_type  \
# 194                  32.0        HD         1      LED         missing
# 231                  32.0        HD         1      LED         missing
# 413                  32.0        HD         1      LED         missing
# 819                  55.0  Ultra HD         1      LED   4K Resolution
# 952                  55.0  Ultra HD         1      LED   4K Resolution
# 953                  65.0  Ultra HD         1      LED   4K Resolution
# 957                  43.0  Ultra HD         1      LED   4K Resolution
#
#     screen_pixels
# 194      1366x768
# 231      1366x768
# 413      1366x768
# 819     3840x2160
# 952     3840x2160
# 953     3840x2160
# 957     3840x2160

# %%
df = df.drop(columns='smart')

# %%
df.head()
# Out:
#    price  rating    screen_size            wifi                speakers  \
# 0  14999      53  32in, QLED TV  Wifi, Ethernet  2 Speakers, 30W Output
# 1   9999      53   43in, LED TV  Wifi, Ethernet  2 Speakers, 16W Output
# 2  31990      65   43in, LED TV  Wifi, Ethernet  2 Speakers, 20W Output
# 3  38900      63   43in, LED TV  Wifi, Ethernet  2 Speakers, 20W Output
# 4  16249      48   32in, LED TV  Wifi, Ethernet  2 Speakers, 16W Output
#
#                                         processor  \
# 0  Quad Core Processor, 1.5 GB RAM, 16 GB Storage
# 1    Cortex A53 Processor, 1 GB RAM, 8 GB Storage
# 2                       3 HDMI Ports, 2 USB Ports
# 3                          178â€‰Â° Viewing Angle
# 4                          178â€‰Â° Viewing Angle
#
#                             view                                ports  \
# 0  Ultra Slim, 178 Viewing Angle            2 HDMI Ports, 2 USB Ports
# 1              178 Viewing Angle            2 HDMI Ports, 2 USB Ports
# 2          Supports Apps & Games  Screen Mirroring / Miracast Support
# 3      2 HDMI Ports, 1 USB Ports                Supports Apps & Games
# 4      3 HDMI Ports, 2 USB Ports  Screen Mirroring / Miracast Support
#
#      brand tv_size   tv_type      resolution            pixels  \
# 0     acer    32in   QLED TV  1366x768pixels           missing
# 1   xiaomi    43in    LED TV         Full HD   1920x1080pixels
# 2       lg    43in    LED TV   4K Resolution   3840x2160pixels
# 3  samsung    43in    LED TV   4K Resolution   3840x2160pixels
# 4       lg    32in    LED TV  1366x768pixels           missing
#
#   screen_size_from_name        hd  is_smart led_type resolution_type  \
# 0                  32.0        HD         1     QLED         missing
# 1                  43.0   Full HD         1      LED         missing
# 2                  43.0  Ultra HD         1      LED   4K Resolution
# 3                  43.0  Ultra HD         1      LED   4K Resolution
# 4                  32.0        HD         1      LED         missing
#
#   screen_pixels
# 0      1366x768
# 1     1920x1080
# 2     3840x2160
# 3     3840x2160
# 4      1366x768

# %%
for i in df['screen_size'].unique():
    print(i)
# Out:
# 32in, QLED TV
# 43in, LED TV
# 32in, LED TV
# 55in, LED TV
# 65in, QLED TV
# 55in, QLED TV
# 43in, QLED TV
# 292in, MicroLED TV
# 65in, LED TV
# 50in, LED TV
# 32in
# 90in, LED TV
# 86in, LED TV
# 27in
# 40in, LED TV
# 110in, Micro LED TV
# 50in, QLED TV
# 75in, LED TV
# 55in, QNED TV
# 85in, QLED TV
# 98in, OLED TV
# 55in, OLED TV
# 43in, LCD TV
# 31.5in, LED TV
# 98in, QLED TV
# 65in, OLED TV
# 42in, OLED TV
# 58in, LED TV
# 24in, LED TV
# 85in, LED TV
# 75in, QLED TV
# 83in, OLED TV
# 77in, OLED TV
# 54.72in, LED TV
# 98in, LED TV
# 42in, LED TV
# 97in, OLED TV
# 55in
# 98in, QD-LED TV
# 48in, OLED TV
# 60in, LED TV
# 82in, OLED TV
# 43in, OLED TV
# 75in, Mini-LED TV
# 55in, Mini-LED TV
# 65in, Mini-LED TV
# 89in, Mini-LED TV
# 85in, QD-Mini LED TV
# 65in, QD-Mini LED TV
# 75in, QD-Mini LED TV
# 74.41in, LED TV
# 85in, Mini LED TV
# 65in, Mini LED TV
# 100in, Laser TV
# 42.91in, QLED TV
# 55in, Mini LED TV
# 54.72in, QLED TV
# 70in, LED TV
# 100in, Laser TV TV
# 120in, Laser TV TV
# 55.12in, QLED TV
# 42.91in, LED TV
# 75in, OLED TV
# 74.41in, QLED TV
# 64.57in, LED TV
# 49.61in, LED TV
# 88in, OLED TV
# 85in, Mini-LED TV
# 98in, Mini LED QLED TV
# 85in, Mini LED QLED TV
# Mini LED TV
# 39.37in, LED TV
# 89in, Micro LED TV
# 40in, QLED TV
# 86in, OLED TV
# 23.62in, LED TV
# 50in
# 100in, LED TV
# 98in, QD-MiniLED TV
# 65in, QD-LED TV
# 75in, QD-MiniLED TV
# 85in, QD-MiniLED TV
# 58in, QLED TV
# 90in, Laser TV
# 23in, LCD TV
# 48in, LED TV
# 24.02in, LED TV
# 75in, miniLED TV
# 57.48in, LED TV
# 75in, Mini LED TV
# 75in, Full Array LED TV

# %%
pattern = '\b\d+(\.\d+)?in\b'
text = '75.48in, Full Array LED TV'
re.findall(pattern, text)
# Out:
# []

# %%
df['screen_size'] = df['screen_size'].str.split(',').str.get(0).str.replace('in','')

# %%
df.loc[603,'screen_size']  = np.nan

# %%
df['screen_size'] = df['screen_size'].astype(float)

# %%
df['wifi'].unique()
# Out:
# array(['Wifi, Ethernet', 'Wifi', nan, 'missing', 'Ethernet'], dtype=object)

# %%
df['has_wifi'] = df['wifi'].str.contains('Wifi').astype(float)
df['has_ethernet'] = df['wifi'].str.contains('Ethernet').astype(float)

# %%
df.drop(columns='wifi', inplace=True)

# %%
df['speakers'].unique()
# Out:
# array(['2 Speakers, 30W Output', '2 Speakers, 16W Output',
#        '2 Speakers, 20W Output', '2 Speakers, 6W Output',
#        '2 Speakers, 10W Output', '4 Speakers', '56W Output',
#        '2 Speakers, 10â€‰W Output', 'Ultra Slim, 178Â° Viewing Angle',
#        '2 Speakers, 24W Output', '178â€‰Â° Viewing Angle',
#        '2 Speakers, 40W Output', '2 Speakers, 36W Output',
#        '5 Speakers, 104W Output', '4 Speakers, 24W Output', '100W Output',
#        '35W Output', '2 Speakers, 60W Output', '4 Speakers, 25W Output',
#        '2 Speakers, 48W Output', '80W Output', '2 Speakers, 76W Output',
#        '50W Output', '3 Speakers, 84W Output', '4 Speakers, 60W Output',
#        '20W Output', '4 Speakers, 40W Output', '60W Output', '40W Output',
#        'Ultra Slim', '70W Output', '7 Speakers, 70W Output',
#        '5 Speakers, 50W Output', '2 Speakers, 15W Output',
#        '2 Speakers, 20â€‰W Output', '204W Output',
#        '3 Speakers, 60W Output', '2 Speakers, 50W Output',
#        '5 Speakers, 60W Output', '4 HDMI Ports, 2 USB Ports',
#        '2 HDMI Ports, 2 USB Ports', '2 Speakers, 19W Output',
#        '4.2.2CH Speakers, 70W Output',
#        'â€ŽMali G31 MP2 700MHz Processor, 1.5 GB RAM, 8 GB Storage',
#        '4.1 Speakers, 100W Output', '2 Speakers, 8W Output',
#        '3 Speakers, 30W Output', '4 Speakers, 30W Output',
#        '2 Speakers, 12W Output', '7 Speakers, 90W Output', '120W Output',
#        '300W Output', '2 GB RAM, 32 GB Storage', '4 Speakers, 48W Output',
#        '30W Output', '95W Output', '136W Output',
#        '3 HDMI Ports, 2 USB Ports', '2 Speakers, 24â€‰W Output',
#        '150W Output', '160W Output', '4 Speakers, 70W Output',
#        'Screen Mirroring / Miracast Support', 'Supports Apps & Games',
#        '90W Output',
#        '2Ã—12.5W, surround channels 2Ã—10W, subwoofer 20W Output',
#        '178Â° Viewing Angle', '2 Speakers, 16â€‰W Output',
#        'REGZA Processor', '2 Speakers, 25W Output', '10W Output',
#        'missing', 'Quad Core Processor, 2 GB RAM, 16 GB Storage',
#        '3 Speakers, 61W Output', '2 Speakers, 18W Output',
#        '50 Speakers, 25W Output', '2 Speakers, 2W Output', '2 Speakers',
#        '2 Speakers, 48â€‰W Output', '2 Speakers, 1W Output',
#        '2 Speakers, 40â€‰W Output', '2 GB RAM, 16 GB Storage',
#        '2 Speakers, 28W Output', '6 Speakers, 102W Output', '25W Output',
#        '16W Output', '3 Speakers, 49W Output',
#        '2.1 Channel Speakers, 60W Output',
#        '60 Watts Output, ONKYO Speaker with Built-in 20 W Subwoofer Speakers, 60W Output',
#        '4 Speakers, 100W Output', '8 Speakers, 30W Output',
#        '4.2.2 Speakers, 60W Output', '2.2CH Speakers, 40W Output',
#        '2.2.2CH Speakers, 60W Output', '4.2.2CH Speakers, 60W Output',
#        '1.5 GB RAM, 8 GB Storage', '2 Speakers, 20 Output',
#        '4 Speakers, 36W Output', 'Cognitive Processor XR Processor',
#        '4.2 Speakers, 80W Output'], dtype=object)

# %%
temp = df[~df['speakers'].str.contains('Speakers')]

# %%
temp['speakers'].unique()
# Out:
# array(['56W Output', 'Ultra Slim, 178Â° Viewing Angle',
#        '178â€‰Â° Viewing Angle', '100W Output', '35W Output',
#        '80W Output', '50W Output', '20W Output', '60W Output',
#        '40W Output', 'Ultra Slim', '70W Output', '204W Output',
#        '4 HDMI Ports, 2 USB Ports', '2 HDMI Ports, 2 USB Ports',
#        'â€ŽMali G31 MP2 700MHz Processor, 1.5 GB RAM, 8 GB Storage',
#        '120W Output', '300W Output', '2 GB RAM, 32 GB Storage',
#        '30W Output', '95W Output', '136W Output',
#        '3 HDMI Ports, 2 USB Ports', '150W Output', '160W Output',
#        'Screen Mirroring / Miracast Support', 'Supports Apps & Games',
#        '90W Output',
#        '2Ã—12.5W, surround channels 2Ã—10W, subwoofer 20W Output',
#        '178Â° Viewing Angle', 'REGZA Processor', '10W Output', 'missing',
#        'Quad Core Processor, 2 GB RAM, 16 GB Storage',
#        '2 GB RAM, 16 GB Storage', '25W Output', '16W Output',
#        '1.5 GB RAM, 8 GB Storage', 'Cognitive Processor XR Processor'],
#       dtype=object)

# %%
filt = (temp['speakers'].str.contains('Processor')) | (temp['speakers'].str.contains('Ports')) | (temp['speakers'].str.contains('View'))
temp.loc[filt]
# Out:
#         price  rating  screen_size  \
# 23    8800000      79        292.0
# 59      99999      45         27.0
# 275    599999      82         77.0
# 276    299999      81         98.0
# 338      9780      52         32.0
# 430   8311799      84         89.0
# 564     82000      54         55.0
# 646     19990      42         32.0
# 663    418099      64        100.0
# 668     49999      63         43.0
# 704    155999      79         75.0
# 717     17900      39         43.0
# 741     47999      72         65.0
# 953    102990      74         65.0
# 1008   599999      79         42.0
# 1009  1499999      76         75.0
# 1010   233990      75         75.0
# 1012   299990      83         65.0
#
#                                                speakers  \
# 23                      Ultra Slim, 178Â° Viewing Angle
# 59                               178â€‰Â° Viewing Angle
# 275                           4 HDMI Ports, 2 USB Ports
# 276                           2 HDMI Ports, 2 USB Ports
# 338   â€ŽMali G31 MP2 700MHz Processor, 1.5 GB RAM, ...
# 430                     Ultra Slim, 178Â° Viewing Angle
# 564                           3 HDMI Ports, 2 USB Ports
# 646                                 178Â° Viewing Angle
# 663                                     REGZA Processor
# 668                           4 HDMI Ports, 2 USB Ports
# 704                           3 HDMI Ports, 2 USB Ports
# 717                                 178Â° Viewing Angle
# 741        Quad Core Processor, 2 GB RAM, 16 GB Storage
# 953                              178â€‰Â° Viewing Angle
# 1008                                178Â° Viewing Angle
# 1009                                178Â° Viewing Angle
# 1010                   Cognitive Processor XR Processor
# 1012                   Cognitive Processor XR Processor
#
#                                 processor  \
# 23                              3D TV: No
# 59              2 HDMI Ports, 2 USB Ports
# 275   Screen Mirroring / Miracast Support
# 276                                 3D TV
# 338                178â€‰Â° Viewing Angle
# 430             4 HDMI Ports, 3 USB Ports
# 564                 Supports Apps & Games
# 646             2 HDMI Ports, 2 USB Ports
# 663                            Ultra Slim
# 668                 Supports Apps & Games
# 704                             3D TV: No
# 717                   60â€‰Hz, 16:9 Ratio
# 741                178â€‰Â° Viewing Angle
# 953             3 HDMI Ports, 2 USB Ports
# 1008            3 HDMI Ports, 2 USB Ports
# 1009            4 HDMI Ports, 3 USB Ports
# 1010               178â€‰Â° Viewing Angle
# 1012               178â€‰Â° Viewing Angle
#
#                                      view  \
# 23    Screen Mirroring / Miracast Support
# 59                              3D TV: No
# 275                              120â€‰Hz
# 276   Screen Mirroring / Miracast Support
# 338             2 HDMI Ports, 3 USB Ports
# 430   Screen Mirroring / Miracast Support
# 564                            16:9 Ratio
# 646                 Supports Apps & Games
# 663   Screen Mirroring / Miracast Support
# 668   Screen Mirroring / Miracast Support
# 704   Screen Mirroring / Miracast Support
# 717                               missing
# 741             2 HDMI Ports, 2 USB Ports
# 953   Screen Mirroring / Miracast Support
# 1008  Screen Mirroring / Miracast Support
# 1009                            3D TV: No
# 1010            3 HDMI Ports, 2 USB Ports
# 1012            3 HDMI Ports, 2 USB Ports
#
#                                     ports       brand tv_size  \
# 23                                  120Hz     samsung   292in
# 59    Screen Mirroring / Miracast Support  16"9 Ratio      lg
# 275                               missing        sony    77in
# 276                                 120Hz        sony    98in
# 338                 Supports Apps & Games      beston    32in
# 430                                 120Hz     samsung    89in
# 564                               missing       telly    55in
# 646   Screen Mirroring / Miracast Support     hyundai    32in
# 663                                 144Hz     toshiba   100in
# 668                               missing      amazon    43in
# 704                                 120Hz         tcl    75in
# 717                               missing      garuda    43in
# 741                 Supports Apps & Games        sens    65in
# 953                   50â€‰Hz, 16:9 Ratio     samsung    65in
# 1008                                120Hz        sony    42in
# 1009                Supports Apps & Games        sony    75in
# 1010                Supports Apps & Games        sony    75in
# 1012  Screen Mirroring / Miracast Support        sony    65in
#
#                  tv_type      resolution            pixels  \
# 23           MicroLED TV   8K Resolution   7680x4320pixels
# 59                  27in         missing              Wifi
# 275              OLED TV   4K Resolution   3840x2160pixels
# 276              OLED TV   4K Resolution   3840x2160pixels
# 338               LED TV  1366x768pixels           missing
# 430          Mini-LED TV   4K Resolution   3840x2160pixels
# 564              missing   4K Resolution   3840x2160pixels
# 646               LED TV  1366x768pixels           missing
# 663               LED TV   4K Resolution   3840x2160pixels
# 668              QLED TV   4K Resolution   3840x2160pixels
# 704              OLED TV   4K Resolution   3840x2160pixels
# 717               LED TV         Full HD   1920x1080pixels
# 741              QLED TV   4K Resolution   3840x2160pixels
# 953               LED TV   4K Resolution   3840x2160pixels
# 1008             OLED TV   4K Resolution   3840x2160pixels
# 1009         Mini LED TV   8K Resolution   7680x4320pixels
# 1010   Full Array LED TV   4K Resolution   3840x2160pixels
# 1012             OLED TV   4K Resolution   3840x2160pixels
#
#      screen_size_from_name        hd  is_smart  led_type resolution_type  \
# 23                 missing  Ultra HD         1  MicroLED   8K Resolution
# 59                 missing      27.0         1         0         missing
# 275                   77.0  Ultra HD         1   missing   4K Resolution
# 276                   98.0  Ultra HD         1   missing   4K Resolution
# 338                   32.0        HD         1       LED         missing
# 430                   89.0  Ultra HD         1       LED   4K Resolution
# 564                   55.0  Ultra HD         1   missing   4K Resolution
# 646                   32.0   missing         1       LED         missing
# 663                  100.0  Ultra HD         1   missing   4K Resolution
# 668                   43.0  Ultra HD         1      QLED   4K Resolution
# 704                   75.0  Ultra HD         1   missing   4K Resolution
# 717                   43.0   Full HD         1       LED         missing
# 741                   65.0  Ultra HD         1      QLED   4K Resolution
# 953                   65.0  Ultra HD         1       LED   4K Resolution
# 1008                  42.0  Ultra HD         1   missing   4K Resolution
# 1009                  75.0  Ultra HD         1       LED   8K Resolution
# 1010                  75.0  Ultra HD         1       LED   4K Resolution
# 1012                  65.0  Ultra HD         1   missing   4K Resolution
#
#      screen_pixels  has_wifi  has_ethernet
# 23       7680x4320       1.0           0.0
# 59         missing       0.0           0.0
# 275      3840x2160       1.0           1.0
# 276      3840x2160       1.0           1.0
# 338       1366x768       1.0           1.0
# 430      3840x2160       1.0           0.0
# 564      3840x2160       1.0           0.0
# 646       1366x768       1.0           0.0
# 663      3840x2160       1.0           0.0
# 668      3840x2160       1.0           1.0
# 704      3840x2160       1.0           1.0
# 717      1920x1080       1.0           0.0
# 741      3840x2160       1.0           1.0
# 953      3840x2160       1.0           1.0
# 1008     3840x2160       1.0           0.0
# 1009     7680x4320       1.0           1.0
# 1010     3840x2160       1.0           1.0
# 1012     3840x2160       1.0           0.0

# %%
x = temp.loc[[338,663,741,1010,1012], 'speakers':'ports'].shift(1, axis=1).values 
df.loc[[338,663,741,1010,1012], 'speakers':'ports'] = x

# %%
x = temp.loc[[23,59,430,646,717,953,1008,1009], 'speakers':'ports'].shift(2, axis=1).values 
df.loc[[23,59,430,646,717,953,1008,1009], 'speakers':'ports'] = x

# %%
x = temp.loc[[275,276,564,668,704], 'speakers':'ports'].shift(3, axis=1).values
df.loc[[275,276,564,668,704], 'speakers':'ports'] = x

# %%
df['speakers'].unique()
# Out:
# array(['2 Speakers, 30W Output', '2 Speakers, 16W Output',
#        '2 Speakers, 20W Output', '2 Speakers, 6W Output',
#        '2 Speakers, 10W Output', '4 Speakers', '56W Output',
#        '2 Speakers, 10â€‰W Output', nan, '2 Speakers, 24W Output',
#        '2 Speakers, 40W Output', '2 Speakers, 36W Output',
#        '5 Speakers, 104W Output', '4 Speakers, 24W Output', '100W Output',
#        '35W Output', '2 Speakers, 60W Output', '4 Speakers, 25W Output',
#        '2 Speakers, 48W Output', '80W Output', '2 Speakers, 76W Output',
#        '50W Output', '3 Speakers, 84W Output', '4 Speakers, 60W Output',
#        '20W Output', '4 Speakers, 40W Output', '60W Output', '40W Output',
#        'Ultra Slim', '70W Output', '7 Speakers, 70W Output',
#        '5 Speakers, 50W Output', '2 Speakers, 15W Output',
#        '2 Speakers, 20â€‰W Output', '204W Output',
#        '3 Speakers, 60W Output', '2 Speakers, 50W Output',
#        '5 Speakers, 60W Output', '2 Speakers, 19W Output',
#        '4.2.2CH Speakers, 70W Output', '4.1 Speakers, 100W Output',
#        '2 Speakers, 8W Output', '3 Speakers, 30W Output',
#        '4 Speakers, 30W Output', '2 Speakers, 12W Output',
#        '7 Speakers, 90W Output', '120W Output', '300W Output',
#        '2 GB RAM, 32 GB Storage', '4 Speakers, 48W Output', '30W Output',
#        '95W Output', '136W Output', '2 Speakers, 24â€‰W Output',
#        '150W Output', '160W Output', '4 Speakers, 70W Output',
#        'Screen Mirroring / Miracast Support', 'Supports Apps & Games',
#        '90W Output',
#        '2Ã—12.5W, surround channels 2Ã—10W, subwoofer 20W Output',
#        '2 Speakers, 16â€‰W Output', '2 Speakers, 25W Output',
#        '10W Output', 'missing', '3 Speakers, 61W Output',
#        '2 Speakers, 18W Output', '50 Speakers, 25W Output',
#        '2 Speakers, 2W Output', '2 Speakers', '2 Speakers, 48â€‰W Output',
#        '2 Speakers, 1W Output', '2 Speakers, 40â€‰W Output',
#        '2 GB RAM, 16 GB Storage', '2 Speakers, 28W Output',
#        '6 Speakers, 102W Output', '25W Output', '16W Output',
#        '3 Speakers, 49W Output', '2.1 Channel Speakers, 60W Output',
#        '60 Watts Output, ONKYO Speaker with Built-in 20 W Subwoofer Speakers, 60W Output',
#        '4 Speakers, 100W Output', '8 Speakers, 30W Output',
#        '4.2.2 Speakers, 60W Output', '2.2CH Speakers, 40W Output',
#        '2.2.2CH Speakers, 60W Output', '4.2.2CH Speakers, 60W Output',
#        '1.5 GB RAM, 8 GB Storage', '2 Speakers, 20 Output',
#        '4 Speakers, 36W Output', '4.2 Speakers, 80W Output'], dtype=object)

# %%
df['num_speakers'] = df['speakers'].str.split(',').str.get(0).str.split(' ').str.get(0).fillna(0)

# %%
pattern = r'(\d+(\.\d+\.\d+)?)(?=\s*Speakers)'
text = '4 Speakers'
re.findall(pattern,text)
# Out:
# [('4', '')]

# %%
df['num_speakers'] = df['speakers'].fillna('missing').apply(lambda x: re.findall(r'(\d+(\.\d+\.\d+)?)(?=\s*Speakers)', x)).str.get(0).str.get(0)

# %%
df['speakers'] = df['speakers'].str.replace('â€‰','')

# %%
pattern = r'\b\d+\bW Output'
text = '20W Output'
re.findall(pattern,text)
# Out:
# []

# %%
df['speaker_output'] = df['speakers'].fillna('missing').apply(lambda x: re.findall(r'\d+W Output', x)).str.get(0).str.split('W').str.get(0).astype(float)

# %%
df[['speakers', 'num_speakers', 'speaker_output']].sample(7)
# Out:
#                    speakers num_speakers  speaker_output
# 228  2 Speakers, 40W Output            2            40.0
# 773  2 Speakers, 20W Output            2            20.0
# 587  2 Speakers, 20W Output            2            20.0
# 915  2 Speakers, 24W Output            2            24.0
# 434  2 Speakers, 24W Output            2            24.0
# 864  2 Speakers, 20W Output            2            20.0
# 758  2 Speakers, 20W Output            2            20.0

# %%
df.drop(columns='speakers', inplace=True)

# %%
df.head()
# Out:
#    price  rating  screen_size                                       processor  \
# 0  14999      53         32.0  Quad Core Processor, 1.5 GB RAM, 16 GB Storage
# 1   9999      53         43.0    Cortex A53 Processor, 1 GB RAM, 8 GB Storage
# 2  31990      65         43.0                       3 HDMI Ports, 2 USB Ports
# 3  38900      63         43.0                          178â€‰Â° Viewing Angle
# 4  16249      48         32.0                          178â€‰Â° Viewing Angle
#
#                             view                                ports  \
# 0  Ultra Slim, 178 Viewing Angle            2 HDMI Ports, 2 USB Ports
# 1              178 Viewing Angle            2 HDMI Ports, 2 USB Ports
# 2          Supports Apps & Games  Screen Mirroring / Miracast Support
# 3      2 HDMI Ports, 1 USB Ports                Supports Apps & Games
# 4      3 HDMI Ports, 2 USB Ports  Screen Mirroring / Miracast Support
#
#      brand tv_size   tv_type      resolution  ... screen_size_from_name  \
# 0     acer    32in   QLED TV  1366x768pixels  ...                  32.0
# 1   xiaomi    43in    LED TV         Full HD  ...                  43.0
# 2       lg    43in    LED TV   4K Resolution  ...                  43.0
# 3  samsung    43in    LED TV   4K Resolution  ...                  43.0
# 4       lg    32in    LED TV  1366x768pixels  ...                  32.0
#
#          hd is_smart  led_type resolution_type screen_pixels has_wifi  \
# 0        HD        1      QLED         missing      1366x768      1.0
# 1   Full HD        1       LED         missing     1920x1080      1.0
# 2  Ultra HD        1       LED   4K Resolution     3840x2160      1.0
# 3  Ultra HD        1       LED   4K Resolution     3840x2160      1.0
# 4        HD        1       LED         missing      1366x768      1.0
#
#    has_ethernet  num_speakers speaker_output
# 0           1.0             2           30.0
# 1           1.0             2           16.0
# 2           1.0             2           20.0
# 3           1.0             2           20.0
# 4           1.0             2           16.0
#
# [5 rows x 21 columns]

# %%
df.drop(columns='screen_size_from_name', inplace=True)

# %%
temp = df[df['processor'].fillna('missing').str.contains('View')]
x = temp.loc[:,'processor':'ports'].shift(1, axis=1).values 
df.loc[temp.index, 'processor':'ports'] = x

# %%
pattern = '\w+ Core'
text = 'Quad Core Processor, 1.5 GB RAM, 16 GB Storage'
re.findall(pattern, text)
# Out:
# ['Quad Core']

# %%
df['processor_core'] = df['processor'].fillna('missing').apply(lambda x: re.findall(r'\w+ Core', x)).str.get(0)

# %%
df['processor_core'].unique()
# Out:
# array(['Quad Core', nan, 'Octa Core', 'Hexa Core'], dtype=object)

# %%
def convert_core_to_num(text):
    text = str(text).lower()
    if text:
        if 'quad' in text:
            return 4
        elif 'hexa' in text:
            return 6
        elif 'octa' in text:
            return 8
        else:
            return np.nan

# %%
df['processor_core'] = df['processor_core'].apply(convert_core_to_num).astype(float)

# %%
df['processor_core'].unique()
# Out:
# array([ 4., nan,  8.,  6.])

# %%
# extract ram
pattern = r'\b\d+(\.\d+)?\s?GB RAM\b'
pattern2 = r'\d+(\.\d+)?GB RAM'
pattern3 = r'\b\d+(\.\d+)?\bGB RAM'
 # '\b\d+(\.\d+)?in\b'
text = 'Cortex A53 Processor, 1.5 GB RAM, 8 GB Storage'
re.findall(pattern3, text)
# Out:
# []

# %%
df['processor']
# Out:
# 0         Quad Core Processor, 1.5 GB RAM, 16 GB Storage
# 1           Cortex A53 Processor, 1 GB RAM, 8 GB Storage
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#                               ...
# 1015      Cortex A35 Processor, 1.5 GB RAM, 8 GB Storage
# 1016                             2 GB RAM, 16 GB Storage
# 1017                                                 NaN
# 1018    ARM Cortex A53 Processor, 2 GB RAM, 8 GB Storage
# 1019    ARM Cortex A53 Processor, 2 GB RAM, 8 GB Storage
# Name: processor, Length: 1020, dtype: object

# %%
# extracting inbuilt storage
pattern = r'(\d+(\.\d+)?\s*(?:[KkMmGg][Bb])?\s*Storage)'
text = 'Cortex A53 Processor, 1 GB RAM, 8 MB Storage'
re.findall(pattern, text)
# Out:
# [('8 MB Storage', '')]

# %%
df['processor_ram']=  df['processor'].fillna('missing').apply(lambda x: re.findall('(\d+(\.\d+)?\s*(?:[KkMmGg][Bb])?\s*RAM)', x)).str.get(0).str.get(0)

# %%
df['processor_inbuilt_storage'] = df['processor'].fillna('missing').apply(lambda x: re.findall(r'(\d+(\.\d+)?\s*(?:[KkMmGg][Bb])?\s*Storage)', x)).str.get(0).str.get(0)

# %%
def convert(text):
    if 'GB' in text:
        return text.split(' ')[0]
    elif 'MB' in text:
        return float(text.split(' ')[0])/1024
    else:
        return np.nan
    
df['processor_ram'] = df['processor_ram'].fillna('missing').apply(convert)

# %%
df['processor_inbuilt_storage'] = df['processor_inbuilt_storage'].fillna('missing').apply(convert)

# %%
df.loc[946,['processor','processor_core', 'processor_ram', 'processor_inbuilt_storage' ]]
# Out:
# processor                    Cortex A73 64-bit Quad Core Processor, 3 GB RA...
# processor_core                                                             4.0
# processor_ram                                                                3
# processor_inbuilt_storage                                                   32
# Name: 946, dtype: object

# %%
temp = df[df['processor'].fillna('missing').str.contains('Ports')]
x = temp.loc[:,'processor':'ports'].shift(2,axis=1).values
df.loc[temp.index, 'processor':'ports'] = x

# %%
pattern = '(\d+(\.\d+)?\s*(?:[KkMmGg][Bb])?\s*RAM)'
text = '51.2 MB RAM, 4 GB Storage'
re.findall(pattern, text)
# Out:
# [('51.2 MB RAM', '.2')]

# %%
df[['processor','processor_core', 'processor_ram','processor_inbuilt_storage']].sample(7)
# Out:
#                                             processor  processor_core  \
# 373  ARM Cortex A53 Processor, 1 GB RAM, 8 GB Storage             NaN
# 115           CA53 Processor, 2 GB RAM, 16 GB Storage             NaN
# 489      Quad Core Processor, 2 GB RAM, 16 GB Storage             4.0
# 40                                                NaN             NaN
# 440            A73 Processor, 4 GB RAM, 64 GB Storage             NaN
# 918                     Quad Core Processor Processor             4.0
# 434       Quad Core Processor, 1 GB RAM, 8 GB Storage             4.0
#
#     processor_ram processor_inbuilt_storage
# 373             1                         8
# 115             2                        16
# 489             2                        16
# 40            NaN                       NaN
# 440             4                        64
# 918           NaN                       NaN
# 434             1                         8

# %%
df.drop(columns='processor', inplace=True)

# %%
df['view'].unique()
# Out:
# array(['Ultra Slim, 178 Viewing Angle', '178 Viewing Angle', nan,
#        '178â€‰Â° Viewing Angle', '1 HDMI Ports, 2 USB Ports',
#        '3 HDMI Ports, 2 USB Ports', 'Ultra Slim',
#        'Ultra Slim, 178â€‰Â° Viewing Angle',
#        'Ultra Slim, 178Â° Viewing Angle', '4 HDMI Ports, 2 USB Ports',
#        '2 HDMI Ports, 2 USB Ports', '180 Viewing Angle',
#        '6 HDMI Ports, 3 USB Ports', '4 HDMI Ports, 3 USB Ports',
#        '179 Viewing Angle', '4 HDMI Ports, 4 USB Ports',
#        '178Â° Viewing Angle', 'HDMI', '60â€‰Hz', '120â€‰Hz',
#        '3 HDMI Ports, 1 USB Ports', 'missing', '60â€‰Hz, 16:9 Ratio',
#        '180â€‰Â° Viewing Angle', '8Â° Viewing Angle',
#        '170â€‰Â° Viewing Angle', '170Â° Viewing Angle'], dtype=object)

# %%
df.insert(5,'extra_features', value=np.nan)

# %%
temp = df[df['view'].fillna('missing').str.contains('Ports')]

# %%
x = temp.loc[:,'view':'extra_features'].shift(1, axis=1).values
df.loc[temp.index, 'view':'extra_features'] = x

# %%
df['view']= df['view'].str.replace('â€‰Â°','').str.replace('â€‰','').str.replace('Â°','')

# %%
df['view'].unique()
# Out:
# array(['Ultra Slim, 178 Viewing Angle', '178 Viewing Angle', nan,
#        'Ultra Slim', '180 Viewing Angle', '179 Viewing Angle', 'HDMI',
#        '60Hz', '120Hz', 'missing', '60Hz, 16:9 Ratio', '8 Viewing Angle',
#        '170 Viewing Angle'], dtype=object)

# %%
df['is_ultra_slim'] = df['view'].str.contains('Ultra Slim').astype(float)

# %%
pattern = r'\d+ Viewing Angle'
text = 'Ultra Slim, 178 Viewing Angle'
re.findall(pattern, text)
# Out:
# ['178 Viewing Angle']

# %%
df['viewing_angle'] = df['view'].fillna('missing').apply(lambda x: re.findall(r'\d+ Viewing Angle', x)).str.get(0).str.split(' ').str.get(0).astype(float)

# %%
df.drop(columns='view', inplace=True)

# %% [markdown]
# # ports

# %%
df['ports'].unique()
# Out:
# array(['2 HDMI Ports, 2 USB Ports', '3 HDMI Ports, 2 USB Ports',
#        '2 HDMI Ports, 1 USB Ports', '1 HDMI Ports, 2 USB Ports',
#        '3 HDMI Ports, 1 USB Ports', '3D TV: No',
#        '4 HDMI Ports, 2 USB Ports', '3 HDMI Ports, 3 USB Ports',
#        '4 HDMI Ports, 1 USB Ports', '6 HDMI Ports, 3 USB Ports',
#        '4 HDMI Ports, 3 USB Ports', 'HDMI, 3 USB Ports',
#        '1 HDMI Ports, 1 USB Ports', '4 HDMI Ports, 4 USB Ports',
#        '2 HDMI Ports, 3 USB Ports', 'Supports Apps & Games',
#        '3 HDMI Ports', 'missing', 'Screen Mirroring / Miracast Support',
#        '60â€‰Hz, 16:9 Ratio', '60Hz, 16:9 Ratio', 'HDMI, 2 USB Ports',
#        'HDMI', '2 HDMI Ports', '1 HDMI Ports, 3 USB Ports'], dtype=object)

# %%
filt = (df['ports'].str.contains('Ports')) | (df['ports'] == 'missing')

df[~filt]
# Out:
#        price  rating  screen_size                                ports  \
# 23   8800000      79        292.0                            3D TV: No
# 440   194499      62         85.0                Supports Apps & Games
# 441   102999      60         65.0                Supports Apps & Games
# 442   137299      61         75.0                Supports Apps & Games
# 663   418099      64        100.0  Screen Mirroring / Miracast Support
# 717    17900      39         43.0                  60â€‰Hz, 16:9 Ratio
# 806    94990      64         70.0                     60Hz, 16:9 Ratio
# 819    82480      51         55.0                            3D TV: No
# 841    79999      64         65.0                                 HDMI
# 854    72999      60         55.0                     60Hz, 16:9 Ratio
#
#     extra_features      brand tv_size          tv_type     resolution  \
# 23             NaN    samsung   292in      MicroLED TV  8K Resolution
# 440            NaN        tcl    85in   QD-Mini LED TV  4K Resolution
# 441            NaN        tcl    65in   QD-Mini LED TV  4K Resolution
# 442            NaN        tcl    75in   QD-Mini LED TV  4K Resolution
# 663            NaN    toshiba   100in           LED TV  4K Resolution
# 717            NaN     garuda    43in           LED TV        Full HD
# 806            NaN         lg    70in           LED TV  4K Resolution
# 819            NaN       sony    55in           LED TV  4K Resolution
# 841            NaN    hisense    65in           LED TV  4K Resolution
# 854            NaN  zebronics    55in           LED TV  4K Resolution
#
#                pixels  ... screen_pixels  has_wifi has_ethernet num_speakers  \
# 23    7680x4320pixels  ...     7680x4320       1.0          0.0          NaN
# 440   3840x2160pixels  ...     3840x2160       1.0          0.0            7
# 441   3840x2160pixels  ...     3840x2160       1.0          0.0            7
# 442   3840x2160pixels  ...     3840x2160       1.0          0.0            7
# 663   3840x2160pixels  ...     3840x2160       1.0          0.0          NaN
# 717   1920x1080pixels  ...     1920x1080       1.0          0.0          NaN
# 806   3840x2160pixels  ...     3840x2160       1.0          1.0            2
# 819   3840x2160pixels  ...     3840x2160       0.0          1.0            2
# 841   3480x2160pixels  ...     3480x2160       1.0          1.0          NaN
# 854   3840x2160pixels  ...     3840x2160       1.0          1.0            2
#
#     speaker_output  processor_core  processor_ram processor_inbuilt_storage  \
# 23             NaN             NaN            NaN                       NaN
# 440           90.0             NaN              4                        64
# 441           90.0             NaN              4                        64
# 442           90.0             NaN              4                        64
# 663            NaN             NaN            NaN                       NaN
# 717            NaN             NaN            NaN                       NaN
# 806           20.0             NaN            NaN                       NaN
# 819           10.0             NaN            NaN                        16
# 841           25.0             NaN              4                       NaN
# 854           20.0             NaN            1.5                         8
#
#      is_ultra_slim  viewing_angle
# 23             1.0          178.0
# 440            0.0            NaN
# 441            0.0            NaN
# 442            0.0            NaN
# 663            1.0            NaN
# 717            0.0          178.0
# 806            0.0          178.0
# 819            0.0          178.0
# 841            0.0          178.0
# 854            0.0          178.0
#
# [10 rows x 24 columns]

# %%
# rows that have values of extra_features column in ports column
idx = [440,441,442,663]
df.loc[idx,'extra_features'] = df.loc[idx, 'ports']

# %%
df.loc[idx, 'ports'] = np.nan

# %%
pattern = r'\d+ USB Ports'
text = '2 HDMI Ports, 2 USB Ports'
re.findall(pattern, text)
# Out:
# ['2 USB Ports']

# %%
df['num_hdmi_ports'] = df['ports'].fillna('missing').apply(lambda x: re.findall(r'\d+ HDMI Ports', x)).str.get(0).str.split(' ').str.get(0).astype(float)

# %%
df['num_usb_ports'] = df['ports'].fillna('missing').apply(lambda x: re.findall(r'\d+ USB Ports', x)).str.get(0).str.split(' ').str.get(0).astype(float)

# %%
df[['ports', 'num_hdmi_ports', 'num_usb_ports']].sample(7)
# Out:
#                          ports  num_hdmi_ports  num_usb_ports
# 625  4 HDMI Ports, 3 USB Ports             4.0            3.0
# 396  2 HDMI Ports, 2 USB Ports             2.0            2.0
# 49   3 HDMI Ports, 2 USB Ports             3.0            2.0
# 193  3 HDMI Ports, 2 USB Ports             3.0            2.0
# 437  3 HDMI Ports, 2 USB Ports             3.0            2.0
# 822  3 HDMI Ports, 2 USB Ports             3.0            2.0
# 464  3 HDMI Ports, 2 USB Ports             3.0            2.0

# %%
df.drop(columns='ports', inplace=True)

# %% [markdown]
# # extra features

# %%
df['extra_features'].isna().mean()
# Out:
# 0.8666666666666667

# %% [markdown]
# - around 87% values in extra_features column are null so, dropping that

# %%
df.drop(columns='extra_features', inplace=True)

# %%
df.head()
# Out:
#    price  rating  screen_size    brand tv_size   tv_type      resolution  \
# 0  14999      53         32.0     acer    32in   QLED TV  1366x768pixels
# 1   9999      53         43.0   xiaomi    43in    LED TV         Full HD
# 2  31990      65         43.0       lg    43in    LED TV   4K Resolution
# 3  38900      63         43.0  samsung    43in    LED TV   4K Resolution
# 4  16249      48         32.0       lg    32in    LED TV  1366x768pixels
#
#              pixels        hd  is_smart  ... has_ethernet num_speakers  \
# 0           missing        HD         1  ...          1.0            2
# 1   1920x1080pixels   Full HD         1  ...          1.0            2
# 2   3840x2160pixels  Ultra HD         1  ...          1.0            2
# 3   3840x2160pixels  Ultra HD         1  ...          1.0            2
# 4           missing        HD         1  ...          1.0            2
#
#   speaker_output  processor_core  processor_ram processor_inbuilt_storage  \
# 0           30.0             4.0            1.5                        16
# 1           16.0             NaN              1                         8
# 2           20.0             NaN            NaN                       NaN
# 3           20.0             NaN            NaN                       NaN
# 4           16.0             NaN            NaN                       NaN
#
#    is_ultra_slim  viewing_angle num_hdmi_ports num_usb_ports
# 0            1.0          178.0            2.0           2.0
# 1            0.0          178.0            2.0           2.0
# 2            NaN            NaN            3.0           2.0
# 3            0.0          178.0            2.0           1.0
# 4            0.0          178.0            3.0           2.0
#
# [5 rows x 24 columns]

# %%
df.to_csv('tv_cleaned_v1.csv')
